# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# Many Requirements<p>
# 問題文と提出先　https://atcoder.jp/contests/abc165/tasks/abc165_c<p>
# よく使いそうな関数を、Toolsにまとめておきます。コンテスト前にファイルを作っておいて、入れておくと便利です。

# %%
# %%writefile atcoder.py
def in2ilist():
  return list(map(int,input().split()))

n,m,q=in2ilist()
a=[0]*q
b=[0]*q
c=[0]*q
d=[0]*q
for i in range(q):
  a[i],b[i],c[i],d[i]=in2ilist()
  a[i]-=1
  b[i]-=1

####
####

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 3 4 3
# 1 3 3 100
# 1 2 2 10
# 2 3 2 10

# %%
# %cat test1 | python3 atcoder.py

# %% [markdown]
# 110

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 4 6 10
# 2 4 1 86568
# 1 4 0 90629
# 2 3 0 90310
# 3 4 1 29211
# 3 4 3 78537
# 3 4 2 8580
# 1 2 1 96263
# 1 4 2 2156
# 1 2 0 94325
# 1 4 3 94328

# %%
# %cat test2 | python3 atcoder.py

# %% [markdown]
# 357500

# %% [markdown]
# # 入力例3

# %%
# %%writefile test3
# 10 10 1
# 1 10 9 1

# %%
# %cat test3 | python3 atcoder.py

# %% [markdown]
# 1

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。

# %% [markdown]
# # Tools

# %%
# %%writefile tools.py
from collections import deque
import sys
sys.setrecursionlimit(1000000)

def in2ilist():
  return list(map(int,input().split()))

def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def in2shw(_h):
  _A=[]
  for _ in range(_h):
    _a=input()
    _A.append(_a)
  return _A

def make_edge(_n,_m,_directed=False,_margin=1):
  _e=[]
  for i in range(_n):
    _e.append([])
  for i in range(M):
    _u,_v = in2ilist()
    _e[_u-_margin].append(_v-_margin)
    if not _directed:
      _e[_v-_margin].append(_u-_margin)
  return _e
