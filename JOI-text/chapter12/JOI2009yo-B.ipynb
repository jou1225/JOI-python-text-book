# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# コンテスト<p>
# 問題文と提出先　https://atcoder.jp/contests/joi2009yo/tasks/joi2009yo_b<p>
# よく使いそうな関数を、Toolsにまとめておきます。コンテスト前にファイルを作っておいて、入れておくと便利です。

# %%
# %%writefile atcoder.py
w=[]
k=[]
for i in range(10):
  w1=int(input())
  w.append(w1)
for i in range(10):
  k1=int(input())
  k.append(k1)
  
####
####

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 23
# 23
# 20
# 15
# 15
# 14
# 13
# 9
# 7
# 6
# 25
# 19
# 17
# 17
# 16
# 13
# 12
# 11
# 9
# 5

# %%
# %cat test1 | python3 atcoder.py

# %% [markdown]
# 66 61

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 17
# 25
# 23
# 25
# 79
# 29
# 1
# 61
# 59
# 100
# 44
# 74
# 94
# 57
# 13
# 54
# 82
# 0
# 42
# 45

# %%
# %cat test2 | python3 atcoder.py

# %% [markdown]
# 240 250

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。

# %% [markdown]
# # Tools

# %%
# %%writefile tools.py
from collections import deque
import sys
sys.setrecursionlimit(1000000)

def in2ilist():
  return list(map(int,input().split()))

def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def in2shw(_h):
  _A=[]
  for _ in range(_h):
    _a=input()
    _A.append(_a)
  return _A

def make_edge(_n,_m,_directed=False,_margin=1):
  _e=[]
  for i in range(_n):
    _e.append([])
  for i in range(M):
    _u,_v = in2ilist()
    _e[_u-_margin].append(_v-_margin)
    if not _directed:
      _e[_v-_margin].append(_u-_margin)
  return _e
