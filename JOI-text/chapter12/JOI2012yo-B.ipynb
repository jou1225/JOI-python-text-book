# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# Soccer<p>
# 問題文と提出先　https://atcoder.jp/contests/joi2012yo/tasks/joi2012yo_b<p>
# よく使いそうな関数を、Toolsにまとめておきます。コンテスト前にファイルを作っておいて、入れておくと便利です。

# %%
# %%writefile atcoder.py
def in2ilist():
  return list(map(int,input().split()))


n = int(input())
a=[]
b=[]
c=[]
d=[]
for i in range((n*(n-1))/2):
  a1,b1,c1,d1=in2ilist()
  a.append(a1)
  b.append(b1)
  c.append(c1)
  d.append(d1)

####
####

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 4
# 1 2 0 1
# 1 3 2 1
# 1 4 2 2
# 2 3 1 1
# 2 4 3 0
# 3 4 1 3

# %%
# %cat test1 | python3 atcoder.py

# %% [markdown]
# 2
# 1
# 4
# 2

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 5
# 1 2 1 1
# 3 4 3 1
# 5 1 1 2
# 2 3 0 0
# 4 5 2 3
# 1 3 0 2
# 5 2 2 2
# 4 1 4 5
# 3 5 4 0
# 2 4 0 1

# %%
# %cat test2 | python3 atcoder.py

# %% [markdown]
# 2
# 4
# 1
# 4
# 3

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。

# %% [markdown]
# # Tools

# %%
# %%writefile tools.py
from collections import deque
import sys
sys.setrecursionlimit(1000000)

def in2ilist():
  return list(map(int,input().split()))

def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def in2shw(_h):
  _A=[]
  for _ in range(_h):
    _a=input()
    _A.append(_a)
  return _A

def make_edge(_n,_m,_directed=False,_margin=1):
  _e=[]
  for i in range(_n):
    _e.append([])
  for i in range(M):
    _u,_v = in2ilist()
    _e[_u-_margin].append(_v-_margin)
    if not _directed:
      _e[_v-_margin].append(_u-_margin)
  return _e
