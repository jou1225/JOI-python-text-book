# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# ボールの移動<p>
# 問題文と提出先　https://atcoder.jp/contests/joi2022yo1c/tasks/joi2022_yo1c_d<p>
# よく使いそうな関数を、Toolsにまとめておきます。コンテスト前にファイルを作っておいて、入れておくと便利です。

# %%
# %%writefile atcoder.py
def in2ilist():
  return list(map(int,input().split()))

n,m=in2ilist()
x=[]
y=[]
for i in range(m):
  x1,y1=in2ilist()
  x.append(x1)
  y.append(y1)

####
####

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 3 4
# 1 2
# 3 2
# 2 1
# 1 3

# %%
# %cat test1 | python3 atcoder.py

# %% [markdown]
# 3
# 1
# 2

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 3 3
# 1 1
# 2 2
# 3 3

# %%
# %cat test2 | python3 atcoder.py

# %% [markdown]
# 1
# 2
# 3

# %% [markdown]
# # 入力例3

# %%
# %%writefile test3
# 4 2
# 1 3
# 2 4

# %%
# %cat test3 | python3 atcoder.py

# %% [markdown]
# 3
# 4
# 3
# 4

# %% [markdown]
# # 入力例4

# %%
# %%writefile test4
# 4 8
# 1 3
# 3 2
# 2 4
# 2 3
# 4 1
# 2 1
# 1 4
# 3 3

# %%
# %cat test4 | python3 atcoder.py

# %% [markdown]
# 4
# 1
# 3
# 1

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。

# %% [markdown]
# # Tools

# %%
# %%writefile tools.py
from collections import deque
import sys
sys.setrecursionlimit(1000000)

def in2ilist():
  return list(map(int,input().split()))

def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def in2shw(_h):
  _A=[]
  for _ in range(_h):
    _a=input()
    _A.append(_a)
  return _A

def make_edge(_n,_m,_directed=False,_margin=1):
  _e=[]
  for i in range(_n):
    _e.append([])
  for i in range(M):
    _u,_v = in2ilist()
    _e[_u-_margin].append(_v-_margin)
    if not _directed:
      _e[_v-_margin].append(_u-_margin)
  return _e
