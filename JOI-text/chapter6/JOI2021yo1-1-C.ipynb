# %% [markdown]
# # コード作成

# %% [markdown]
# ####
# の間にコードを記入します。<br>
# 問題文や解説などは本を参照してください。<p>
# 共通要素<p>
# 問題文と提出先　https://atcoder.jp/contests/joi2021yo1a/tasks/joi2021_yo1a_c<p>
# よく使いそうな関数を、Toolsにまとめておきます。コンテスト前にファイルを作っておいて、入れておくと便利です。

# %%
# %%writefile atcoder.py
def in2ilist():
  return list(map(int,input().split()))

n,m=in2ilist()
a=in2ilist()
b=in2ilist()

####
####

# %% [markdown]
# # 入力例1

# %%
# %%writefile test1
# 6 5
# 2 4 6 8 10 12
# 15 12 9 6 3

# %%
# %cat test1 | python3 atcoder.py

# %% [markdown]
# 6
# 12

# %% [markdown]
# # 入力例2

# %%
# %%writefile test2
# 3 5
# 100 100 100
# 100 100 100 100 100

# %%
# %cat test2 | python3 atcoder.py

# %% [markdown]
# 100

# %% [markdown]
# # 入力例3

# %%
# %%writefile test3
# 1 1
# 2
# 5

# %%
# %cat test3 | python3 atcoder.py

# %% [markdown]
# # 入力例4

# %%
# %%writefile test4
# 10 10
# 76 91 98 7 98 7 98 10 63 91
# 70 71 10 10 91 70 65 10 63 76

# %%
# %cat test4 | python3 atcoder.py

# %% [markdown]
# 10
# 63
# 76
# 91

# %% [markdown]
# # 提出
# 1行目の　%%writefile atcoder.py　を入れないで提出します。

# %% [markdown]
# # Tools

# %%
# %%writefile tools.py
from collections import deque
import sys
sys.setrecursionlimit(1000000)

def in2ilist():
  return list(map(int,input().split()))

def in2ihw(_h):
  _A=[]
  for _ in range(_h):
    _a=list(map(int,input().split()))
    _A.append(_a)
  return _A

def in2shw(_h):
  _A=[]
  for _ in range(_h):
    _a=input()
    _A.append(_a)
  return _A

def make_edge(_n,_m,_directed=False,_margin=1):
  _e=[]
  for i in range(_n):
    _e.append([])
  for i in range(M):
    _u,_v = in2ilist()
    _e[_u-_margin].append(_v-_margin)
    if not _directed:
      _e[_v-_margin].append(_u-_margin)
  return _e
